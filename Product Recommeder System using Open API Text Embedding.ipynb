# %% [markdown]
# # **Welcome to the notebook**

# %% [markdown]
# ### Task 1 - Set up project environment

# %% [markdown]
# Installing the needed modules

# %%
# !pip install openai==1.16.2 python-dotenv
# Out:
# Collecting openai==1.16.2
#   Downloading openai-1.16.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (4.67.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.12/dist-packages (from openai==1.16.2) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai==1.16.2) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.16.2) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.16.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.16.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (0.4.2)
# Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.16.0
#     Uninstalling openai-2.16.0:
#       Successfully uninstalled openai-2.16.0
# Successfully installed openai-1.16.2

# %%
# !pip install --upgrade openai httpx python-dotenv
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.16.2)
# Collecting openai
#   Downloading openai-2.17.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.2)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Downloading openai-2.17.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.16.2
#     Uninstalling openai-1.16.2:
#       Successfully uninstalled openai-1.16.2
# Successfully installed openai-2.17.0

# %% [markdown]
# Importing the needed modules and setup the OpenAI API

# %%
import pandas as pd
import numpy as np
import os
from openai import OpenAI
from dotenv import load_dotenv
from matplotlib import pyplot as plt
import plotly.express as px

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# Loading API key and organization ID from a dotenv file
load_dotenv(dotenv_path='/content/apikey.env.txt')

# Retrieving API key and organization ID from environment variables
APIKEY = os.getenv("APIKEY")


# Creating an instance of the OpenAI client with the provided API key and organization ID
client = OpenAI(
  api_key=APIKEY
)

client

# %% [markdown]
# Import our dataset

# %%
data = pd.read_csv("products_dataset.csv")
data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description
# 0     This heavyweight, water-repellent hooded sweat...
# 1     If you need more length between your existing ...
# 2     Polyester cover resembling rich Italian tapest...
# 3     It features a rectangle shape. This vessel set...
# 4     This 9 in. black full grain leather logger boo...
# ...                                                 ...
# 1995  With a stylish monochrome look, this dotty wal...
# 1996  The Abrielle collection features a stunning as...
# 1997  With Fypon balustrade systems, you can transfo...
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...
# 1999  A refreshing take on innovative designs, Safav...
#
# [2000 rows x 3 columns]

# %% [markdown]
# List of last 8 products recently viewed by the user.

# %%
searched_products_id = [
    'P1938',
    'P1970',
    'P1044',
    'P1838',
    'P1048',
    'P1017',
    'P1310',
    'P1444',
]

# %% [markdown]
# ### Task 2 - Prepare the dataset

# %% [markdown]
# Let's label the data points that are recently veiwed.

# %%
data['product_status'] = 'not_viewed'
data.loc[data['product_id'].isin(searched_products_id), 'product_status'] = 'recently_viewed'
data[data.product_status == 'recently_viewed']
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed

# %% [markdown]
# Now let's combine the product `title` and `description` and store it into a column called `combined`.

# %%
data['combined'] = data.title + data.description
data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
# [2000 rows x 5 columns]

# %% [markdown]
# ### Task 3 - Text embedding and visualization

# %% [markdown]
# Creating the text embedding vector

# %%
response = client.embeddings.create(
    input = data.combined.tolist(),
    model = "text-embedding-3-small",
    dimensions= 512
)
vectors = [d.embedding for d in response.data]
data['text_embeddings'] = vectors
data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings
# 0     [0.03744583949446678, 0.03042474389076233, -0....
# 1     [0.03523961082100868, 0.013278326019644737, 0....
# 2     [0.035860564559698105, -0.05905349925160408, 0...
# 3     [-0.05834035575389862, -0.007969953119754791, ...
# 4     [0.01998496614396572, 0.05075598508119583, -0....
# ...                                                 ...
# 1995  [0.08823681622743607, -0.05279356613755226, -0...
# 1996  [0.01092537585645914, -0.040394917130470276, 0...
# 1997  [-0.034084752202034, -0.009548565372824669, 0....
# 1998  [-0.010861445218324661, -0.014231621287763119,...
# 1999  [-0.013586800545454025, -0.012740381062030792,...
#
# [2000 rows x 6 columns]

# %% [markdown]
# > We know that each vector has 512 dimensions. In order to be able to visualize the vectors in a scatter plot, we need to use Principal Component Analysis (PCA) to reduce the dimension from 512 to 2.

# %%
pca = PCA(2)
vector_2d = pca.fit_transform(data.text_embeddings.tolist())
data['pc1'] = vector_2d[:,0]
data['pc2'] = vector_2d[:,1]
data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings       pc1       pc2
# 0     [0.03744583949446678, 0.03042474389076233, -0.... -0.013345  0.071633
# 1     [0.03523961082100868, 0.013278326019644737, 0.... -0.357207  0.236119
# 2     [0.035860564559698105, -0.05905349925160408, 0... -0.201097 -0.206634
# 3     [-0.05834035575389862, -0.007969953119754791, ... -0.181801  0.043378
# 4     [0.01998496614396572, 0.05075598508119583, -0.... -0.214502  0.141177
# ...                                                 ...       ...       ...
# 1995  [0.08823681622743607, -0.05279356613755226, -0... -0.042134 -0.196931
# 1996  [0.01092537585645914, -0.040394917130470276, 0... -0.246671 -0.481560
# 1997  [-0.034084752202034, -0.009548565372824669, 0.... -0.082898  0.103884
# 1998  [-0.010861445218324661, -0.014231621287763119,...  0.506961  0.005647
# 1999  [-0.013586800545454025, -0.012740381062030792,... -0.280890 -0.430880
#
# [2000 rows x 8 columns]

# %% [markdown]
# Now that we have the text embedding vectors in two dimensions, we can use them to create a 2D plot.

# %%
px.scatter(data, x = 'pc1', y = 'pc2', color = 'product_status')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9eef8aa9-3ae7-4cf4-ba90-2b7727cf1cc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9eef8aa9-3ae7-4cf4-ba90-2b7727cf1cc5")) {                    Plotly.newPlot(                        "9eef8aa9-3ae7-4cf4-ba90-2b7727cf1cc5",                        [{"hovertemplate":"product_status=not_viewed\u003cbr\u003epc1=%{x}\u003cbr\u003epc2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not_viewed","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"not_viewed","showlegend":true,"x":[-0.013345258550045118,-0.3572065127458187,-0.2010969727416537,-0.1818012714705404,-0.21450188478352722,-0.19533980132277368,0.4780997647004277,-0.10870094109497903,-0.2823154156426258,-0.30056202167086477,-0.0208856632660569,0.5167815373329968,-0.28029418529059075,-0.18393900009131833,-0.16249070067830615,-0.15418343042517624,0.49157324844334493,-0.18330905026662137,0.5047
head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster BedPolyester cover rese...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                      text_embeddings       pc1       pc2
# 0  [0.03744583949446678, 0.03042474389076233, -0.... -0.013345  0.071633
# 1  [0.03523961082100868, 0.013278326019644737, 0.... -0.357207  0.236119
# 2  [0.035860564559698105, -0.05905349925160408, 0... -0.201097 -0.206634
# 3  [-0.05834035575389862, -0.007969953119754791, ... -0.181801  0.043378
# 4  [0.01998496614396572, 0.05075598508119583, -0.... -0.214502  0.141177

# %% [markdown]
# Get the data related to `recently_viewed` and `not_viewed` products

# %%
df_recently_viewed = data[data.product_status == 'recently_viewed']
df_not_viewed = data[data.product_status == 'not_viewed']
df_not_viewed
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings       pc1       pc2
# 0     [0.03744583949446678, 0.03042474389076233, -0.... -0.013345  0.071633
# 1     [0.03523961082100868, 0.013278326019644737, 0.... -0.357207  0.236119
# 2     [0.035860564559698105, -0.05905349925160408, 0... -0.201097 -0.206634
# 3     [-0.05834035575389862, -0.007969953119754791, ... -0.181801  0.043378
# 4     [0.01998496614396572, 0.05075598508119583, -0.... -0.214502  0.141177
# ...                                                 ...       ...       ...
# 1995  [0.08823681622743607, -0.05279356613755226, -0... -0.042134 -0.196931
# 1996  [0.01092537585645914, -0.040394917130470276, 0... -0.246671 -0.481560
# 1997  [-0.034084752202034, -0.009548565372824669, 0.... -0.082898  0.103884
# 1998  [-0.010861445218324661, -0.014231621287763119,...  0.506961  0.005647
# 1999  [-0.013586800545454025, -0.012740381062030792,... -0.280890 -0.430880
#
# [1992 rows x 8 columns]

# %% [markdown]
# Convert the embedding vectors to Numpy arrays

# %%
vectors_recently_viewed = np.array(df_recently_viewed.text_embeddings.tolist())
vectors_not_viewed = np.array(df_not_viewed.text_embeddings.tolist())

# %% [markdown]
# Find the similarity between each viewed product and all the unviewed products.

# %%
similarity_matrix = cosine_similarity(vectors_recently_viewed, vectors_not_viewed)
top_ids = []
for row in similarity_matrix:
  top_id = np.argmax(row)
  top_ids.append(top_id)
most_similiar_product_ids = list(df_not_viewed.iloc[top_ids].product_id)
most_similiar_product_ids
# Out:
# ['P854', 'P1061', 'P1705', 'P733', 'P1327', 'P1705', 'P1059', 'P314']

# %% [markdown]
# ### Task 5 - Recommend products based on the searched products

# %% [markdown]
# Let's update the status of the top similar products to `recommended`.

# %%
data.loc[data.product_id.isin(most_similiar_product_ids), 'product_status'] = 'recommended'
data[data.product_status == "recommended"]
# Out:
#      product_id                                              title  \
# 314        P314  8 oz. #230F-7 Florence Brown Semi-Gloss Enamel...
# 733        P733  5 gal. #N440-1 Streetwise Extra Durable Semi-G...
# 854        P854  1 qt. #N460-1 Evening White Satin Enamel Inter...
# 1059      P1059  1 gal. Home Decorators Collection #HDC-SP14-6 ...
# 1061      P1061  1 gal. #MQ1-28 Orange Flambe One-Coat Hide Egg...
# 1327      P1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1705      P1705  5 gal. #310D-4 Gold Buff Extra Durable Satin E...
#
#                                             description product_status  \
# 314   Introducing the best of BEHR Paint. Featuring ...    recommended
# 733   BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 854   Love your space like never before with the hig...    recommended
# 1059  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1061  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1327  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 1705  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
#
#                                                combined  \
# 314   8 oz. #230F-7 Florence Brown Semi-Gloss Enamel...
# 733   5 gal. #N440-1 Streetwise Extra Durable Semi-G...
# 854   1 qt. #N460-1 Evening White Satin Enamel Inter...
# 1059  1 gal. Home Decorators Collection #HDC-SP14-6 ...
# 1061  1 gal. #MQ1-28 Orange Flambe One-Coat Hide Egg...
# 1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1705  5 gal. #310D-4 Gold Buff Extra Durable Satin E...
#
#                                         text_embeddings       pc1       pc2
# 314   [-0.003966080024838448, -0.057984184473752975,...  0.486927 -0.060005
# 733   [0.010829787701368332, -0.01894751563668251, 0...  0.468495 -0.009424
# 854   [0.03936273232102394, -0.017813587561249733, 0...  0.493101 -0.052187
# 1059  [-0.0021748889703303576, -0.05987035483121872,...  0.448110 -0.054049
# 1061  [0.014321798458695412, -0.024152863770723343, ...  0.491525 -0.066632
# 1327  [0.04926867410540581, -0.019617563113570213, 0...  0.473394 -0.065312
# 1705  [-0.002173374406993389, -0.013826336711645126,...  0.467003 -0.037503

# %% [markdown]
# Let's visualize the recommended products.

# %%
px.scatter(data, x= 'pc1', y = 'pc2', color = "product_status", hover_data = "title")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="03cc5a99-8686-4090-9b6f-fbbef5cfd66c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03cc5a99-8686-4090-9b6f-fbbef5cfd66c")) {                    Plotly.newPlot(                        "03cc5a99-8686-4090-9b6f-fbbef5cfd66c",                        [{"customdata":[["Men's 3X Large Carbon Heather Cotton\u002fPolyester Rain Defender Paxton Heavyweight Hooded Zip-Front Sweatshirt"],["Turmode 30 ft. RP TNC Female to RP TNC Male Adapter Cable"],["Large Tapestry Bolster Bed"],["16-Gauge-Sinks Vessel Sink in White with Faucet"],["Men's Crazy Horse 9'' Logger Boot - Steel Toe - Black Size 10.5(W)"],["Mariana 6 ft. Multi-Color 3-Panel Screen Divider"],["5 gal. #650C-2 Powdery Mist Semi-Gloss Interior Paint"],["7\u002f8 in. x 4-1\u002f2 in. x 0.045 in. Metal and Stainless Cutting Wheel (50-Pack)"],["Ring Gold Bar Cart"],["Traditional Silver Wooden Vanity Table"],["15 in. x 59 in. Open Louvered Polypropylene Shutters Pair in Peppercorn"],["1 qt. #350F-7 Wild Mushroom Semi-Gloss Enamel Low Odor Interior Paint & Primer"],